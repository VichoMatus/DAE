# %% [markdown]
# # Guion de Grabación Interactivo con Locución – DAE ACTIVA
#
# Este cuaderno Jupyter contiene la guía definitiva para grabar tu video de presentación. Cada paso incluye las acciones técnicas de la interfaz de usuario (**"Haz esto"**) y el libreto de voz sugerido (**"Di esto"**) para que la explicación sea fluida, clara y profesional.

# %% [markdown]
# ### Inicialización de Datos para la Demostración ("Cocina de TV")
#
# Ejecuta la siguiente celda de código para limpiar la base de datos e inyectar exactamente los 3 activos del video. De esta forma, podrás mostrar todo el recorrido sin demoras de digitación:

# %%
# Ejecutar el inicializador de base de datos de video
# !./.venv/bin/python backend/seed_video.py

# %% [markdown]
# ---
#
# ## Paso 1: Creación de Solicitud Inicial (Inicio del Ciclo)
#
# * **Rol:** **Jefe de Área**
#
# * **Haz esto:**
#   1. Abre el navegador en [http://localhost:3000/login](http://localhost:3000/login).
#   2. Escribe `jefe_gomez` en el campo *Usuario* y `demo1234` en el campo *Contraseña*. Haz clic en **"Iniciar Sesión"**.
#   3. En la sección superior **"Nueva Solicitud de Asignación"**, realiza las siguientes selecciones:
#      * Dropdown *Colaborador:* Selecciona **Roberto Ramírez**.
#      * Dropdown *Perfil Cargo:* Selecciona **Desarrollador / TI**.
#      * Dropdown *Categoría Requerida:* Selecciona **MacBook Pro M3**.
#      * Input *Justificación / Motivo:* Escribe `"Ingreso de desarrollador Senior al equipo core."`
#   4. Haz clic en el botón verde **"Enviar Solicitud de Asignación"**.
#
# * **Di esto:**
#   > *"Comenzamos el flujo de demostración iniciando sesión como Jefe de Área. Nuestra tarea es solicitar un nuevo equipo de trabajo para el colaborador Roberto Ramírez, quien ingresa con el cargo de Desarrollador TI. Rellenamos la categoría MacBook Pro M3 solicitada, ingresamos la justificación y presionamos Enviar. Como ven, la solicitud ha quedado registrada exitosamente en estado Pendiente."*

# %% [markdown]
# ---
#
# ## Paso 2: Despacho de Inventario y Validación de Compatibilidad (Compuerta D1)
#
# * **Rol:** **Encargado de Bodega**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Encargado de Bodega"**.
#   2. Haz clic en el botón **"Registrar Nuevo Activo"** para abrir el formulario.
#      * Muestra que el calendario bloquea la selección de fechas futuras.
#      * Escribe `-100` en *Valor Original* y muestra que el botón de registro queda deshabilitado.
#      * Cierra el formulario presionando **"Registrar Nuevo Activo"** de nuevo.
#   3. En la sección inferior **"Compuerta D1: Control de Stock y Compatibilidad Técnica"**:
#      * Dropdown *1. Seleccionar Solicitud:* Selecciona la solicitud de **Roberto Ramírez**.
#      * Dropdown *2. Seleccionar Activo en Stock:* Selecciona el activo **`UCT-TI-2024-001` (Dell Latitude 5440)**.
#      * Haz clic en el botón verde **"Despachar a TI (En Tránsito)"**.
#      * *Resultado:* Aparecerá la advertencia roja de incompatibilidad técnica D1.
#   4. Ahora, en el Dropdown *2. Seleccionar Activo en Stock*, selecciona el equipo **`UCT-VID-001` (MacBook Pro M3, 18GB RAM)**.
#   5. Haz clic en el botón verde **"Despachar a TI (En Tránsito)"**.
#
# * **Di esto:**
#   > *"Ahora cambiamos al rol de Encargado de Bodega. Demostraremos la Compuerta D1 de compatibilidad técnica. Si intentamos despachar un equipo Dell Latitude de 8GB de RAM para una solicitud de Desarrollador TI, el backend bloquea automáticamente la transacción informando que el cargo requiere un mínimo de 16GB de RAM. Procedemos a seleccionar el MacBook Pro M3 compatible y presionamos Despachar a TI. El despacho se realiza con éxito y el equipo cambia al estado En Tránsito."*

# %% [markdown]
# ---
#
# ## Paso 3: Configuración y Notificación de TI
#
# * **Rol:** **Técnico TI**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Soporte y Técnico TI"**.
#   2. En la sección **"Preparación de Nuevas Asignaciones"**, busca la tarjeta del activo **`UCT-VID-001`**.
#   3. Haz clic en el botón azul **"Confirmar Recepción y Formatear"** (cambia a *En Configuración*).
#   4. Haz clic en el botón verde **"Completar Configuración Técnica"** (cambia a *Listo para Entrega*).
#   5. Haz clic en el botón morado **"Notificar Retiro a Colaborador"** (cambia a *Pendiente de Recepción Formal*).
#
# * **Di esto:**
#   > *"Ingresamos a la consola del Técnico de TI. Confirmamos la recepción física del hardware para la carga de perfiles y sistema operativo, lo que cambia el estado a En Configuración. Posteriormente marcamos la configuración técnica como completada, dejándolo Listo para Entrega, y finalmente notificamos al colaborador. La máquina de estados del backend garantiza que este orden se cumpla estrictamente sin saltos de estado."*

# %% [markdown]
# ---
#
# ## Paso 4: Firma Digital y Traspaso de Custodia
#
# * **Rol:** **Colaborador**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Colaborador (Portal de Firma)"**.
#   2. En la sección *"Equipos Pendientes de Firma de Acta"*, busca la tarjeta del equipo **`UCT-VID-002`**.
#   3. En la caja de texto *Escribe tu firma legal aquí*, escribe: `"Roberto Ramírez Silva"`.
#   4. Haz clic en el botón verde **"Estampar Firma y Recibir Activo"**.
#
# * **Di esto:**
#   > *"El colaborador Roberto Ramírez inicia sesión en su portal y visualiza el acta digital del equipo UCT-VID-002. Para recibir el hardware, ingresa su firma digital y confirma la recepción. Al estampar la firma, observamos que el custodio físico y el responsable administrativo en la base de datos cambian oficialmente a su nombre, finalizando el traspaso civil del hardware."*

# %% [markdown]
# ---
#
# ## Paso 5: Reporte de Falla y Evaluación D2 por Alto Costo
#
# * **Rol:** **Técnico TI**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Soporte y Técnico TI"**.
#   2. Desplázate a la sección inferior **"Diagnósticos Pendientes de Evaluación D2"** donde se muestra el activo **`UCT-VID-003`** (precargado en estado *En Diagnóstico*).
#   3. **Demostración de Error:** Escribe `-150000` en la caja de costo y haz clic en **"Evaluar Compuerta D2"** (observa el banner de error rojo del backend).
#   4. **Demostración de Bloqueo por Costo:** Limpia la caja y escribe `1500000` (costo mayor al precio nuevo). Haz clic en **"Evaluar Compuerta D2"**.
#
# * **Di esto:**
#   > *"Ahora demostraremos el control de incidentes y la compuerta D2. El equipo UCT-VID-003 presenta fallas graves y se encuentra En Diagnóstico. Si intentamos ingresar un valor de reparación negativo, el backend rechaza la petición por seguridad. Al ingresar un costo de reparación de 1 millón y medio de pesos, que supera el costo de reposición de un equipo nuevo, el backend de Flask lo detecta como no rentable y lo redirige automáticamente al estado Pendiente de Decisión contable de Finanzas."*

# %% [markdown]
# ---
#
# ## Paso 6: Aprobación Extraordinaria con Justificación Contable (Compuerta D3)
#
# * **Rol:** **Finanzas y Control**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Finanzas y Control"**.
#   2. En la sección **"Decisiones Financieras Pendientes (Compuerta D3)"**, localiza el activo **`UCT-VID-003`**.
#   3. Muestra la alerta roja de parámetros de salud excedidos (Batería 45% y 4 fallas).
#   4. **Demostración de Error (HTTP 422):** Deja el campo de justificación vacío e intenta hacer clic en **"Autorizar Extensión (1 Año)"**.
#   5. **Demostración de Aprobación Exitosa:** Escribe en la caja de texto: `"Se autoriza la prórroga por razones operacionales y de presupuesto de TI anual"` y haz clic en el botón.
#
# * **Di esto:**
#   > *"Pasamos al rol de Finanzas. Evaluamos la compuerta D3 sobre el activo UCT-VID-003. Vemos una alerta roja indicando desgaste crítico de batería y fallas reiteradas. Si intentamos aprobar la extensión sin justificación contable, la petición es rechazada con un código HTTP 422. Escribiremos un justificativo contable formal de al menos 20 caracteres y presionamos el botón. La extensión se realiza con éxito y el activo se prorroga por 12 meses."*

# %% [markdown]
# ---
#
# ## Paso 7: Trazabilidad e Historial Inmutable
#
# * **Rol:** **Auditoría**
#
# * **Haz esto:**
#   1. En el sidebar izquierdo, haz clic en el botón de rol **"Auditoría y Supervisión"**.
#   2. Busca el equipo **`UCT-VID-003`** en la lista y haz clic en el botón **"Ver Trazabilidad"**.
#
# * **Di esto:**
#   > *"Para cerrar la presentación, ingresamos con el rol de Auditoría. Al consultar la trazabilidad del activo, podemos ver la línea de tiempo inmutable con todo su historial desde su creación, los diagnósticos del técnico, hasta el justificativo ingresado por Finanzas. Esta inmutabilidad erradica la responsabilidad difusa de los activos tecnológicos de la universidad. Muchas gracias."*
